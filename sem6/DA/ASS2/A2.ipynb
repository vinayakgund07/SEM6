# %%
#Q1-a
import pandas as pd                                                         
































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

transactions=[['bread','milk'],
              ['bread','diaper','beer','eggs'],
              ['milk','diaper','beer','coke'],
              ['bread','milk','diaper','beer'],
              ['bread','milk','diaper','coke']]

te=TransactionEncoder()
te_array=te.fit(transactions).transform(transactions)
df=pd.DataFrame(te_array,columns=te.columns_)
print(df)

#for min_support 0.5
print("\nFor min_support 0.5\n")
freq_items=apriori(df,min_support=0.5,use_colnames=True)
print(freq_items)
rules=association_rules(freq_items,metric='support',min_threshold=0.05)
rules=rules.sort_values(['support','confidence'],ascending=[False,False])
rules
# Out:
#     beer  bread   coke  diaper   eggs   milk
# 0  False   True  False   False  False   True
# 1   True   True  False    True   True  False
# 2   True  False   True    True  False   True
# 3   True   True  False    True  False   True
# 4  False   True   True    True  False   True
#
# For min_support 0.5
#
#    support                    itemsets
# 0      0.6           frozenset({beer})
# 1      0.8          frozenset({bread})
# 2      0.8         frozenset({diaper})
# 3      0.8           frozenset({milk})
# 4      0.6   frozenset({beer, diaper})
# 5      0.6  frozenset({diaper, bread})
# 6      0.6    frozenset({bread, milk})
# 7      0.6   frozenset({diaper, milk})
#            antecedents          consequents  antecedent support  \
# 0    frozenset({beer})  frozenset({diaper})                 0.6
# 1  frozenset({diaper})    frozenset({beer})                 0.8
# 2  frozenset({diaper})   frozenset({bread})                 0.8
# 3   frozenset({bread})  frozenset({diaper})                 0.8
# 4   frozenset({bread})    frozenset({milk})                 0.8
# 5    frozenset({milk})   frozenset({bread})                 0.8
# 6  frozenset({diaper})    frozenset({milk})                 0.8
# 7    frozenset({milk})  frozenset({diaper})                 0.8
#
#    consequent support  support  confidence    lift  representativity  \
# 0                 0.8      0.6        1.00  1.2500               1.0
# 1                 0.6      0.6        0.75  1.2500               1.0
# 2                 0.8      0.6        0.75  0.9375               1.0
# 3                 0.8      0.6        0.75  0.9375               1.0
# 4                 0.8      0.6        0.75  0.9375               1.0
# 5                 0.8      0.6        0.75  0.9375               1.0
# 6                 0.8      0.6        0.75  0.9375               1.0
# 7                 0.8      0.6        0.75  0.9375               1.0
#
#    leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 0      0.12         inf           0.50     0.75      1.000       0.875
# 1      0.12         1.6           1.00     0.75      0.375       0.875
# 2     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 3     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 4     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 5     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 6     -0.04         0.8          -0.25     0.60     -0.250       0.750
# 7     -0.04         0.8          -0.25     0.60     -0.250       0.750

# %%
#q1-b
#for min_support 0.3
print("\nFor min_support 0.3\n")

freq_items=apriori(df,min_support=0.3,use_colnames=True)
print(freq_items)
rules=association_rules(freq_items,metric='support',min_threshold=0.05)
rules=rules.sort_values(['support','confidence'],ascending=[False,False])
rules
# Out:
# For min_support 0.3
#
#     support                          itemsets
# 0       0.6                 frozenset({beer})
# 1       0.8                frozenset({bread})
# 2       0.4                 frozenset({coke})
# 3       0.8               frozenset({diaper})
# 4       0.8                 frozenset({milk})
# 5       0.4          frozenset({beer, bread})
# 6       0.6         frozenset({beer, diaper})
# 7       0.4           frozenset({beer, milk})
# 8       0.6        frozenset({diaper, bread})
# 9       0.6          frozenset({bread, milk})
# 10      0.4         frozenset({coke, diaper})
# 11      0.4           frozenset({coke, milk})
# 12      0.6         frozenset({diaper, milk})
# 13      0.4  frozenset({beer, diaper, bread})
# 14      0.4   frozenset({beer, diaper, milk})
# 15      0.4  frozenset({diaper, bread, milk})
# 16      0.4   frozenset({coke, diaper, milk})
#                    antecedents                 consequents  \
# 2            frozenset({beer})         frozenset({diaper})
# 3          frozenset({diaper})           frozenset({beer})
# 6          frozenset({diaper})          frozenset({bread})
# 7           frozenset({bread})         frozenset({diaper})
# 8           frozenset({bread})           frozenset({milk})
# 9            frozenset({milk})          frozenset({bread})
# 14         frozenset({diaper})           frozenset({milk})
# 15           frozenset({milk})         frozenset({diaper})
# 10           frozenset({coke})         frozenset({diaper})
# 12           frozenset({coke})           frozenset({milk})
# 17    frozenset({beer, bread})         frozenset({diaper})
# 23     frozenset({beer, milk})         frozenset({diaper})
# 34   frozenset({coke, diaper})           frozenset({milk})
# 35     frozenset({coke, milk})         frozenset({diaper})
# 37           frozenset({coke})   frozenset({diaper, milk})
# 0            frozenset({beer})          frozenset({bread})
# 4            frozenset({beer})           frozenset({milk})
# 16   frozenset({beer, diaper})          frozenset({bread})
# 18  frozenset({diaper, bread})           frozenset({beer})
# 19           frozenset({beer})  frozenset({diaper, bread})
# 22   frozenset({beer, diaper})           frozenset({milk})
# 24   frozenset({diaper, milk})           frozenset({beer})
# 25           frozenset({beer})   frozenset({diaper, milk})
# 28  frozenset({diaper, bread})           frozenset({milk})
# 29   frozenset({diaper, milk})          frozenset({bread})
# 30    frozenset({bread, milk})         frozenset({diaper})
# 36   frozenset({diaper, milk})           frozenset({coke})
# 1           frozenset({bread})           frozenset({beer})
# 5            frozenset({milk})           frozenset({beer})
# 11         frozenset({diaper})           frozenset({coke})
# 13           frozenset({milk})           frozenset({coke})
# 20         frozenset({diaper})    frozenset({beer, bread})
# 21          frozenset({bread})   frozenset({beer, diaper})
# 26         frozenset({diaper})     frozenset({beer, milk})
# 27           frozenset({milk})   frozenset({beer, diaper})
# 31         frozenset({diaper})    frozenset({bread, milk})
# 32          frozenset({bread})   frozenset({diaper, milk})
# 33           frozenset({milk})  frozenset({diaper, bread})
# 38         frozenset({diaper})     frozenset({coke, milk})
# 39           frozenset({milk})   frozenset({coke, diaper})
#
#     antecedent support  consequent support  support  confidence      lift  \
# 2                  0.6                 0.8      0.6    1.000000  1.250000
# 3                  0.8                 0.6      0.6    0.750000  1.250000
# 6                  0.8                 0.8      0.6    0.750000  0.937500
# 7                  0.8                 0.8      0.6    0.750000  0.937500
# 8                  0.8                 0.8      0.6    0.750000  0.937500
# 9                  0.8                 0.8      0.6    0.750000  0.937500
# 14                 0.8                 0.8      0.6    0.750000  0.937500
# 15                 0.8                 0.8      0.6    0.750000  0.937500
# 10                 0.4                 0.8      0.4    1.000000  1.250000
# 12                 0.4                 0.8      0.4    1.000000  1.250000
# 17                 0.4                 0.8      0.4    1.000000  1.250000
# 23                 0.4                 0.8      0.4    1.000000  1.250000
# 34                 0.4                 0.8      0.4    1.000000  1.250000
# 35                 0.4                 0.8      0.4    1.000000  1.250000
# 37                 0.4                 0.6      0.4    1.000000  1.666667
# 0                  0.6                 0.8      0.4    0.666667  0.833333
# 4                  0.6                 0.8      0.4    0.666667  0.833333
# 16                 0.6                 0.8      0.4    0.666667  0.833333
# 18                 0.6                 0.6      0.4    0.666667  1.111111
# 19                 0.6                 0.6      0.4    0.666667  1.111111
# 22                 0.6                 0.8      0.4    0.666667  0.833333
# 24                 0.6                 0.6      0.4    0.666667  1.111111
# 25                 0.6                 0.6      0.4    0.666667  1.111111
# 28                 0.6                 0.8      0.4    0.666667  0.833333
# 29                 0.6                 0.8      0.4    0.666667  0.833333
# 30                 0.6                 0.8      0.4    0.666667  0.833333
# 36                 0.6                 0.4      0.4    0.666667  1.666667
# 1                  0.8                 0.6      0.4    0.500000  0.833333
# 5                  0.8                 0.6      0.4    0.500000  0.833333
# 11                 0.8                 0.4      0.4    0.500000  1.250000
# 13                 0.8                 0.4      0.4    0.500000  1.250000
# 20                 0.8                 0.4      0.4    0.500000  1.250000
# 21                 0.8                 0.6      0.4    0.500000  0.833333
# 26                 0.8                 0.4      0.4    0.500000  1.250000
# 27                 0.8                 0.6      0.4    0.500000  0.833333
# 31                 0.8                 0.6      0.4    0.500000  0.833333
# 32                 0.8                 0.6      0.4    0.500000  0.833333
# 33                 0.8                 0.6      0.4    0.500000  0.833333
# 38                 0.8                 0.4      0.4    0.500000  1.250000
# 39                 0.8                 0.4      0.4    0.500000  1.250000
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 2                1.0      0.12         inf       0.500000  0.750000
# 3                1.0      0.12         1.6       1.000000  0.750000
# 6                1.0     -0.04         0.8      -0.250000  0.600000
# 7                1.0     -0.04         0.8      -0.250000  0.600000
# 8                1.0     -0.04         0.8      -0.250000  0.600000
# 9                1.0     -0.04         0.8      -0.250000  0.600000
# 14               1.0     -0.04         0.8      -0.250000  0.600000
# 15               1.0     -0.04         0.8      -0.250000  0.600000
# 10               1.0      0.08         inf       0.333333  0.500000
# 12               1.0      0.08         inf       0.333333  0.500000
# 17               1.0      0.08         inf       0.333333  0.500000
# 23               1.0      0.08         inf       0.333333  0.500000
# 34               1.0      0.08         inf       0.333333  0.500000
# 35               1.0      0.08         inf       0.333333  0.500000
# 37               1.0      0.16         inf       0.666667  0.666667
# 0                1.0     -0.08         0.6      -0.333333  0.400000
# 4                1.0     -0.08         0.6      -0.333333  0.400000
# 16               1.0     -0.08         0.6      -0.333333  0.400000
# 18               1.0      0.04         1.2       0.250000  0.500000
# 19               1.0      0.04         1.2       0.250000  0.500000
# 22               1.0     -0.08         0.6      -0.333333  0.400000
# 24               1.0      0.04         1.2       0.250000  0.500000
# 25               1.0      0.04         1.2       0.250000  0.500000
# 28               1.0     -0.08         0.6      -0.333333  0.400000
# 29               1.0     -0.08         0.6      -0.333333  0.400000
# 30               1.0     -0.08         0.6      -0.333333  0.400000
# 36               1.0      0.16         1.8       1.000000  0.666667
# 1                1.0     -0.08         0.8      -0.500000  0.400000
# 5                1.0     -0.08         0.8      -0.500000  0.400000
# 11               1.0      0.08         1.2       1.000000  0.500000
# 13               1.0      0.08         1.2       1.000000  0.500000
# 20               1.0      0.08         1.2       1.000000  0.500000
# 21               1.0     -0.08         0.8      -0.500000  0.400000
# 26               1.0      0.08         1.2       1.000000  0.500000
# 27               1.0     -0.08         0.8      -0.500000  0.400000
# 31               1.0     -0.08         0.8      -0.500000  0.400000
# 32               1.0     -0.08         0.8      -0.500000  0.400000
# 33               1.0     -0.08         0.8      -0.500000  0.400000
# 38               1.0      0.08         1.2       1.000000  0.500000
# 39               1.0      0.08         1.2       1.000000  0.500000
#
#     certainty  kulczynski
# 2    1.000000    0.875000
# 3    0.375000    0.875000
# 6   -0.250000    0.750000
# 7   -0.250000    0.750000
# 8   -0.250000    0.750000
# 9   -0.250000    0.750000
# 14  -0.250000    0.750000
# 15  -0.250000    0.750000
# 10   1.000000    0.750000
# 12   1.000000    0.750000
# 17   1.000000    0.750000
# 23   1.000000    0.750000
# 34   1.000000    0.750000
# 35   1.000000    0.750000
# 37   1.000000    0.833333
# 0   -0.666667    0.583333
# 4   -0.666667    0.583333
# 16  -0.666667    0.583333
# 18   0.166667    0.666667
# 19   0.166667    0.666667
# 22  -0.666667    0.583333
# 24   0.166667    0.666667
# 25   0.166667    0.666667
# 28  -0.666667    0.583333
# 29  -0.666667    0.583333
# 30  -0.666667    0.583333
# 36   0.444444    0.833333
# 1   -0.250000    0.583333
# 5   -0.250000    0.583333
# 11   0.166667    0.750000
# 13   0.166667    0.750000
# 20   0.166667    0.750000
# 21  -0.250000    0.583333
# 26   0.166667    0.750000
# 27  -0.250000    0.583333
# 31  -0.250000    0.583333
# 32  -0.250000    0.583333
# 33  -0.250000    0.583333
# 38   0.166667    0.750000
# 39   0.166667    0.750000

# %%
#for min_support 0.7
print("\nFor min_support 0.7\n")

freq_items=apriori(df,min_support=0.7,use_colnames=True)
print(freq_items)
rules=association_rules(freq_items,metric='support',min_threshold=0.05)
rules=rules.sort_values(['support','confidence'],ascending=[False,False])
rules
# Out:
# For min_support 0.7
#
#    support             itemsets
# 0      0.8   frozenset({bread})
# 1      0.8  frozenset({diaper})
# 2      0.8    frozenset({milk})
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %%
#Q2
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

transactions=[['pen','pencil','eraser'],
              ['pen','notebook','eraser','sharpener'],
              ['pencil','eraser','sharpener'],
              ['pen','pencil','sharpener'],
              ['pen','pencil','notebook','eraser']]

te=TransactionEncoder()
te_array=te.fit(transactions).transform(transactions)
df=pd.DataFrame(te_array,columns=te.columns_)
print(df)

#for min_support 0.5
print("\nFor min_support 0.5\n")
freq_items=apriori(df,min_support=0.5,use_colnames=True)
print(freq_items)
rules=association_rules(freq_items,metric='support',min_threshold=0.05)
rules=rules.sort_values(['support','confidence'],ascending=[False,False])
rules
# Out:
#    eraser  notebook    pen  pencil  sharpener
# 0    True     False   True    True      False
# 1    True      True   True   False       True
# 2    True     False  False    True       True
# 3   False     False   True    True       True
# 4    True      True   True    True      False
#
# For min_support 0.5
#
#    support                     itemsets
# 0      0.8          frozenset({eraser})
# 1      0.8             frozenset({pen})
# 2      0.8          frozenset({pencil})
# 3      0.6       frozenset({sharpener})
# 4      0.6     frozenset({eraser, pen})
# 5      0.6  frozenset({pencil, eraser})
# 6      0.6     frozenset({pencil, pen})
#            antecedents          consequents  antecedent support  \
# 0  frozenset({eraser})     frozenset({pen})                 0.8
# 1     frozenset({pen})  frozenset({eraser})                 0.8
# 2  frozenset({pencil})  frozenset({eraser})                 0.8
# 3  frozenset({eraser})  frozenset({pencil})                 0.8
# 4  frozenset({pencil})     frozenset({pen})                 0.8
# 5     frozenset({pen})  frozenset({pencil})                 0.8
#
#    consequent support  support  confidence    lift  representativity  \
# 0                 0.8      0.6        0.75  0.9375               1.0
# 1                 0.8      0.6        0.75  0.9375               1.0
# 2                 0.8      0.6        0.75  0.9375               1.0
# 3                 0.8      0.6        0.75  0.9375               1.0
# 4                 0.8      0.6        0.75  0.9375               1.0
# 5                 0.8      0.6        0.75  0.9375               1.0
#
#    leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 0     -0.04         0.8          -0.25      0.6      -0.25        0.75
# 1     -0.04         0.8          -0.25      0.6      -0.25        0.75
# 2     -0.04         0.8          -0.25      0.6      -0.25        0.75
# 3     -0.04         0.8          -0.25      0.6      -0.25        0.75
# 4     -0.04         0.8          -0.25      0.6      -0.25        0.75
# 5     -0.04         0.8          -0.25      0.6      -0.25        0.75

# %%
#for min_support 0.7
print("\nFor min_support 0.7\n")
freq_items=apriori(df,min_support=0.7,use_colnames=True)
print(freq_items)
rules=association_rules(freq_items,metric='support',min_threshold=0.05)
rules=rules.sort_values(['support','confidence'],ascending=[False,False])
rules
# Out:
# For min_support 0.7
#
#    support             itemsets
# 0      0.8  frozenset({eraser})
# 1      0.8     frozenset({pen})
# 2      0.8  frozenset({pencil})
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []

# %%
#for min_support 0.3
print("\nFor min_support 0.3\n")
freq_items=apriori(df,min_support=0.3,use_colnames=True)
print(freq_items)
rules=association_rules(freq_items,metric='support',min_threshold=0.05)
rules=rules.sort_values(['support','confidence'],ascending=[False,False])
rules
# Out:
# For min_support 0.3
#
#     support                            itemsets
# 0       0.8                 frozenset({eraser})
# 1       0.4               frozenset({notebook})
# 2       0.8                    frozenset({pen})
# 3       0.8                 frozenset({pencil})
# 4       0.6              frozenset({sharpener})
# 5       0.4       frozenset({notebook, eraser})
# 6       0.6            frozenset({eraser, pen})
# 7       0.6         frozenset({pencil, eraser})
# 8       0.4      frozenset({eraser, sharpener})
# 9       0.4          frozenset({notebook, pen})
# 10      0.6            frozenset({pencil, pen})
# 11      0.4         frozenset({pen, sharpener})
# 12      0.4      frozenset({pencil, sharpener})
# 13      0.4  frozenset({notebook, eraser, pen})
# 14      0.4    frozenset({pencil, eraser, pen})
#                       antecedents                    consequents  \
# 2             frozenset({eraser})               frozenset({pen})
# 3                frozenset({pen})            frozenset({eraser})
# 4             frozenset({pencil})            frozenset({eraser})
# 5             frozenset({eraser})            frozenset({pencil})
# 10            frozenset({pencil})               frozenset({pen})
# 11               frozenset({pen})            frozenset({pencil})
# 0           frozenset({notebook})            frozenset({eraser})
# 8           frozenset({notebook})               frozenset({pen})
# 16  frozenset({notebook, eraser})               frozenset({pen})
# 17     frozenset({notebook, pen})            frozenset({eraser})
# 19          frozenset({notebook})       frozenset({eraser, pen})
# 7          frozenset({sharpener})            frozenset({eraser})
# 13         frozenset({sharpener})               frozenset({pen})
# 15         frozenset({sharpener})            frozenset({pencil})
# 18       frozenset({eraser, pen})          frozenset({notebook})
# 22    frozenset({pencil, eraser})               frozenset({pen})
# 23       frozenset({pencil, pen})            frozenset({eraser})
# 24       frozenset({eraser, pen})            frozenset({pencil})
# 1             frozenset({eraser})          frozenset({notebook})
# 6             frozenset({eraser})         frozenset({sharpener})
# 9                frozenset({pen})          frozenset({notebook})
# 12               frozenset({pen})         frozenset({sharpener})
# 14            frozenset({pencil})         frozenset({sharpener})
# 20            frozenset({eraser})     frozenset({notebook, pen})
# 21               frozenset({pen})  frozenset({notebook, eraser})
# 25            frozenset({pencil})       frozenset({eraser, pen})
# 26            frozenset({eraser})       frozenset({pencil, pen})
# 27               frozenset({pen})    frozenset({pencil, eraser})
#
#     antecedent support  consequent support  support  confidence      lift  \
# 2                  0.8                 0.8      0.6    0.750000  0.937500
# 3                  0.8                 0.8      0.6    0.750000  0.937500
# 4                  0.8                 0.8      0.6    0.750000  0.937500
# 5                  0.8                 0.8      0.6    0.750000  0.937500
# 10                 0.8                 0.8      0.6    0.750000  0.937500
# 11                 0.8                 0.8      0.6    0.750000  0.937500
# 0                  0.4                 0.8      0.4    1.000000  1.250000
# 8                  0.4                 0.8      0.4    1.000000  1.250000
# 16                 0.4                 0.8      0.4    1.000000  1.250000
# 17                 0.4                 0.8      0.4    1.000000  1.250000
# 19                 0.4                 0.6      0.4    1.000000  1.666667
# 7                  0.6                 0.8      0.4    0.666667  0.833333
# 13                 0.6                 0.8      0.4    0.666667  0.833333
# 15                 0.6                 0.8      0.4    0.666667  0.833333
# 18                 0.6                 0.4      0.4    0.666667  1.666667
# 22                 0.6                 0.8      0.4    0.666667  0.833333
# 23                 0.6                 0.8      0.4    0.666667  0.833333
# 24                 0.6                 0.8      0.4    0.666667  0.833333
# 1                  0.8                 0.4      0.4    0.500000  1.250000
# 6                  0.8                 0.6      0.4    0.500000  0.833333
# 9                  0.8                 0.4      0.4    0.500000  1.250000
# 12                 0.8                 0.6      0.4    0.500000  0.833333
# 14                 0.8                 0.6      0.4    0.500000  0.833333
# 20                 0.8                 0.4      0.4    0.500000  1.250000
# 21                 0.8                 0.4      0.4    0.500000  1.250000
# 25                 0.8                 0.6      0.4    0.500000  0.833333
# 26                 0.8                 0.6      0.4    0.500000  0.833333
# 27                 0.8                 0.6      0.4    0.500000  0.833333
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 2                1.0     -0.04         0.8      -0.250000  0.600000
# 3                1.0     -0.04         0.8      -0.250000  0.600000
# 4                1.0     -0.04         0.8      -0.250000  0.600000
# 5                1.0     -0.04         0.8      -0.250000  0.600000
# 10               1.0     -0.04         0.8      -0.250000  0.600000
# 11               1.0     -0.04         0.8      -0.250000  0.600000
# 0                1.0      0.08         inf       0.333333  0.500000
# 8                1.0      0.08         inf       0.333333  0.500000
# 16               1.0      0.08         inf       0.333333  0.500000
# 17               1.0      0.08         inf       0.333333  0.500000
# 19               1.0      0.16         inf       0.666667  0.666667
# 7                1.0     -0.08         0.6      -0.333333  0.400000
# 13               1.0     -0.08         0.6      -0.333333  0.400000
# 15               1.0     -0.08         0.6      -0.333333  0.400000
# 18               1.0      0.16         1.8       1.000000  0.666667
# 22               1.0     -0.08         0.6      -0.333333  0.400000
# 23               1.0     -0.08         0.6      -0.333333  0.400000
# 24               1.0     -0.08         0.6      -0.333333  0.400000
# 1                1.0      0.08         1.2       1.000000  0.500000
# 6                1.0     -0.08         0.8      -0.500000  0.400000
# 9                1.0      0.08         1.2       1.000000  0.500000
# 12               1.0     -0.08         0.8      -0.500000  0.400000
# 14               1.0     -0.08         0.8      -0.500000  0.400000
# 20               1.0      0.08         1.2       1.000000  0.500000
# 21               1.0      0.08         1.2       1.000000  0.500000
# 25               1.0     -0.08         0.8      -0.500000  0.400000
# 26               1.0     -0.08         0.8      -0.500000  0.400000
# 27               1.0     -0.08         0.8      -0.500000  0.400000
#
#     certainty  kulczynski
# 2   -0.250000    0.750000
# 3   -0.250000    0.750000
# 4   -0.250000    0.750000
# 5   -0.250000    0.750000
# 10  -0.250000    0.750000
# 11  -0.250000    0.750000
# 0    1.000000    0.750000
# 8    1.000000    0.750000
# 16   1.000000    0.750000
# 17   1.000000    0.750000
# 19   1.000000    0.833333
# 7   -0.666667    0.583333
# 13  -0.666667    0.583333
# 15  -0.666667    0.583333
# 18   0.444444    0.833333
# 22  -0.666667    0.583333
# 23  -0.666667    0.583333
# 24  -0.666667    0.583333
# 1    0.166667    0.750000
# 6   -0.250000    0.583333
# 9    0.166667    0.750000
# 12  -0.250000    0.583333
# 14  -0.250000    0.583333
# 20   0.166667    0.750000
# 21   0.166667    0.750000
# 25  -0.250000    0.583333
# 26  -0.250000    0.583333
# 27  -0.250000    0.583333
