# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

np.random.seed(0)

data = pd.DataFrame({
    'TV': np.random.randint(10, 300, 500),
    'Radio': np.random.randint(5, 50, 500),
    'Newspaper': np.random.randint(1, 100, 500),
    'Sales': np.random.randint(5, 50, 500)
})

X = data[['TV', 'Radio', 'Newspaper']]
y = data['Sales']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1
)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(f"MSE: {mean_squared_error(y_test, y_pred):.2f}")
print(f"R² Score: {r2_score(y_test, y_pred):.2f}")

def predict_sales(model):
    tv = float(input("Enter TV advertising budget: "))
    radio = float(input("Enter Radio advertising budget: "))
    newspaper = float(input("Enter Newspaper advertising budget: "))

    input_df = pd.DataFrame(
        [[tv, radio, newspaper]],
        columns=['TV', 'Radio', 'Newspaper']
    )

    prediction = model.predict(input_df)
    print(f"Predicted Sales: {prediction[0]:.2f}")

predict_sales(model)

features = ['TV', 'Radio', 'Newspaper']

for feature in features:
    plt.figure()
    plt.scatter(data[feature], data['Sales'])
    plt.xlabel(f"{feature} Advertising")
    plt.ylabel("Sales")
    plt.title(f"{feature} vs Sales")
    plt.show()

plt.figure()
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs Predicted Sales")
plt.show()
# Out:
# MSE: 180.21
# R² Score: -0.04
# Enter TV advertising budget:  3500
# Enter Radio advertising budget:  4500
# Enter Newspaper advertising budget:  300
# Predicted Sales: -147.34

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

np.random.seed(1)

data = pd.DataFrame({
    'ID': range(1, 501),
    'Flats': np.random.randint(1, 50, 500),
    'Houses': np.random.randint(1, 30, 500),
    'Purchase': np.random.randint(20, 200, 500)
})

X = data[['Flats', 'Houses']]
y = data['Purchase']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1
)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(f"MSE: {mean_squared_error(y_test, y_pred):.2f}")
print(f"R² Score: {r2_score(y_test, y_pred):.2f}")

def predict_purchase(model):
    flats = float(input("Enter number of Flats: "))
    houses = float(input("Enter number of Houses: "))

    input_df = pd.DataFrame(
        [[flats, houses]],
        columns=['Flats', 'Houses']
    )

    prediction = model.predict(input_df)
    print(f"Predicted Purchase Value: {prediction[0]:.2f}")

predict_purchase(model)

features = ['Flats', 'Houses']

for feature in features:
    plt.figure()
    plt.scatter(data[feature], data['Purchase'])
    plt.xlabel(feature)
    plt.ylabel("Purchase")
    plt.title(f"{feature} vs Purchase")
    plt.show()

plt.figure()
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel("Actual Purchase")
plt.ylabel("Predicted Purchase")
plt.title("Actual vs Predicted Purchase")
plt.show()
# Out:
# MSE: 2698.81
# R² Score: -0.04
# Enter number of Flats:  15
# Enter number of Houses:  22
# Predicted Purchase Value: 108.81

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

np.random.seed(2)

data = pd.DataFrame({
    'ID': range(1, 501),
    'Gender': np.random.choice([0, 1], 500),
    'Age': np.random.randint(18, 60, 500),
    'EstimatedSalary': np.random.randint(15000, 150000, 500),
    'Purchased': np.random.choice([0, 1], 500)
})

X = data[['Gender', 'Age', 'EstimatedSalary']]
y = data['Purchased']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1
)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

def predict_car_purchase(model):
    gender = int(input("Enter Gender (0 = Female, 1 = Male): "))
    age = float(input("Enter Age: "))
    salary = float(input("Enter Estimated Salary: "))

    input_df = pd.DataFrame(
        [[gender, age, salary]],
        columns=['Gender', 'Age', 'EstimatedSalary']
    )

    prediction = model.predict(input_df)
    result = "Will Buy Car" if prediction[0] == 1 else "Will Not Buy Car"
    print(result)

predict_car_purchase(model)

features = ['Age', 'EstimatedSalary']

for feature in features:
    plt.figure()
    plt.scatter(data[feature], data['Purchased'])
    plt.xlabel(feature)
    plt.ylabel("Purchased")
    plt.title(f"{feature} vs Purchased")
    plt.show()
# Out:
# Accuracy: 0.5133333333333333
# Confusion Matrix:
#  [[38 39]
#  [34 39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.49      0.51        77
#            1       0.50      0.53      0.52        73
#
#     accuracy                           0.51       150
#    macro avg       0.51      0.51      0.51       150
# weighted avg       0.51      0.51      0.51       150
# Enter Gender (0 = Female, 1 = Male):  0
# Enter Age:  26
# Enter Estimated Salary:  55000
# Will Buy Car
